# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
smoking='Resources/tobacco.csv'
State='Resources/StatePopulation.csv'
weather='Resources/avg_weather_bystate.csv'

# %%
tobacco= pd.read_csv(smoking)
state= pd.read_csv(State)
weather= pd.read_csv(weather)

# %%
state.head()
# Out:
#         State  Population
# 0     Alabama       17464
# 1      Alaska        1746
# 2     Arizona       60013
# 3    Arkansas       12256
# 4  California       56627

# %%
tobacco.head()
# Out:
#    Year        State Smoke everyday Smoke some days Former smoker  \
# 0  1996  Puerto Rico          9.40%           5.10%           16%
# 1  1997  Puerto Rico          9.40%              5%        15.70%
# 2  1998  Puerto Rico         10.10%           5.20%        16.80%
# 3  1999  Puerto Rico          9.70%              4%        15.30%
# 4  2000  Puerto Rico          9.20%           3.90%        15.20%
#
#   Never smoked     Location 1
# 0       69.50%  Puerto Rico\n
# 1       69.90%  Puerto Rico\n
# 2       67.90%  Puerto Rico\n
# 3          71%  Puerto Rico\n
# 4       71.60%  Puerto Rico\n

# %%
sort= tobacco.loc[tobacco["Year"] == 2010]
sort.head(100)
# Out:
#      Year                                     State Smoke everyday  \
# 22   2010                               Puerto Rico          7.50%
# 24   2010                                    Nevada         16.50%
# 49   2010                                 Louisiana         15.90%
# 60   2010                                California          7.50%
# 64   2010                                    Kansas         11.90%
# 93   2010                             Massachusetts         10.20%
# 108  2010                                  Arkansas         17.30%
# 128  2010                                New Jersey         10.20%
# 146  2010                                  New York         10.50%
# 151  2010                                   Arizona         10.70%
# 166  2010                                   Vermont         11.10%
# 186  2010                                   Alabama         15.60%
# 203  2010                                     Idaho         11.30%
# ...

# %%
grouped = sort.set_index('Year')
grouped
# Out:
#                                          State Smoke everyday Smoke some days  \
# Year
# 2010                               Puerto Rico          7.50%           4.40%
# 2010                                    Nevada         16.50%           4.90%
# 2010                                 Louisiana         15.90%           6.20%
# 2010                                California          7.50%           4.60%
# 2010                                    Kansas         11.90%           5.10%
# 2010                             Massachusetts         10.20%           3.90%
# 2010                                  Arkansas         17.30%           5.60%
# 2010                                New Jersey         10.20%           4.20%
# 2010                                  New York         10.50%              5%
# 2010                                   Arizona         10.70%           4.40%
# 2010                                   Vermont         11.10%           4.20%
# ...

# %%
list(grouped.columns)
# Out:
# ['State',
#  'Smoke everyday',
#  'Smoke some days',
#  'Former smoker',
#  'Never smoked',
#  'Location 1']

# %%
grouped
# Out:
#                                          State Smoke everyday Smoke some days  \
# Year
# 2010                               Puerto Rico          7.50%           4.40%
# 2010                                    Nevada         16.50%           4.90%
# 2010                                 Louisiana         15.90%           6.20%
# 2010                                California          7.50%           4.60%
# 2010                                    Kansas         11.90%           5.10%
# 2010                             Massachusetts         10.20%           3.90%
# 2010                                  Arkansas         17.30%           5.60%
# 2010                                New Jersey         10.20%           4.20%
# 2010                                  New York         10.50%              5%
# 2010                                   Arizona         10.70%           4.40%
# 2010                                   Vermont         11.10%           4.20%
# ...

# %%
grouped
# Out:
#                                          State Smoke everyday Smoke some days  \
# Year
# 2010                               Puerto Rico          7.50%           4.40%
# 2010                                    Nevada         16.50%           4.90%
# 2010                                 Louisiana         15.90%           6.20%
# 2010                                California          7.50%           4.60%
# 2010                                    Kansas         11.90%           5.10%
# 2010                             Massachusetts         10.20%           3.90%
# 2010                                  Arkansas         17.30%           5.60%
# 2010                                New Jersey         10.20%           4.20%
# 2010                                  New York         10.50%              5%
# 2010                                   Arizona         10.70%           4.40%
# 2010                                   Vermont         11.10%           4.20%
# ...

# %%
grouped.drop('Location 1', axis=1, inplace=True)

# %%
grouped
# Out:
#                                          State Smoke everyday Smoke some days  \
# Year
# 2010                               Puerto Rico          7.50%           4.40%
# 2010                                    Nevada         16.50%           4.90%
# 2010                                 Louisiana         15.90%           6.20%
# 2010                                California          7.50%           4.60%
# 2010                                    Kansas         11.90%           5.10%
# 2010                             Massachusetts         10.20%           3.90%
# 2010                                  Arkansas         17.30%           5.60%
# 2010                                New Jersey         10.20%           4.20%
# 2010                                  New York         10.50%              5%
# 2010                                   Arizona         10.70%           4.40%
# 2010                                   Vermont         11.10%           4.20%
# ...

# %%
grouped.to_csv("Resources/New_Tobacco.csv",index=False)

# %%
combined_df = pd.merge(grouped,state, how='outer', on='State')
combined_df
# Out:
#                                        State Smoke everyday Smoke some days  \
# 0                                Puerto Rico          7.50%           4.40%
# 1                                     Nevada         16.50%           4.90%
# 2                                  Louisiana         15.90%           6.20%
# 3                                 California          7.50%           4.60%
# 4                                     Kansas         11.90%           5.10%
# 5                              Massachusetts         10.20%           3.90%
# 6                                   Arkansas         17.30%           5.60%
# 7                                 New Jersey         10.20%           4.20%
# 8                                   New York         10.50%              5%
# 9                                    Arizona         10.70%           4.40%
# 10                                   Vermont         11.10%           4.20%
# ...

# %%
final_df= pd.merge(combined_df,weather, how='outer', on='State')
final_df.head(100)
# Out:
#                                        State Smoke everyday Smoke some days  \
# 0                                Puerto Rico          7.50%           4.40%
# 1                                     Nevada         16.50%           4.90%
# 2                                  Louisiana         15.90%           6.20%
# 3                                 California          7.50%           4.60%
# 4                                     Kansas         11.90%           5.10%
# 5                              Massachusetts         10.20%           3.90%
# 6                                   Arkansas         17.30%           5.60%
# 7                                 New Jersey         10.20%           4.20%
# 8                                   New York         10.50%              5%
# 9                                    Arizona         10.70%           4.40%
# 10                                   Vermont         11.10%           4.20%
# ...
