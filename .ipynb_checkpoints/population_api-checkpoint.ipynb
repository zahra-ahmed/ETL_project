# %%
import pandas as pd
import requests
from census import Census
from us import states

# Census API Key
from config import api_key
c = Census(api_key, year=2010)

# %%
census_data = c.acs5.get(("NAME", "B01003_001E"), {'for': 'state:*'})

# %%
census_df = pd.DataFrame(census_data)

# %%
census_df = census_df.rename(columns={"B01003_001E": "Population",
                                      "NAME": "State", "state": "State_no"})

# %%
census_df.head()
# Out:
#         State  Population State_no
# 0     Alabama   4712651.0       01
# 1      Alaska    691189.0       02
# 2     Arizona   6246816.0       04
# 3    Arkansas   2872684.0       05
# 4  California  36637290.0       06

# %%
census_df = census_df[['State', 'Population']]
census_df
# Out:
#                    State  Population
# 0                Alabama   4712651.0
# 1                 Alaska    691189.0
# 2                Arizona   6246816.0
# 3               Arkansas   2872684.0
# 4             California  36637290.0
# 5               Colorado   4887061.0
# 6            Connecticut   3545837.0
# 7               Delaware    881278.0
# 8   District of Columbia    584400.0
# 9                Florida  18511620.0
# 10               Georgia   9468815.0
# 11                Hawaii   1333591.0
# 12                 Idaho   1526797.0
# 13              Illinois  12745359.0
# 14               Indiana   6417398.0
# 15                  Iowa   3016267.0
# 16                Kansas   2809329.0
# 17              Kentucky   4285828.0
# 18             Louisiana   4429940.0
# 19                 Maine   1327665.0
# 20              Maryland   5696423.0
# 21         Massachusetts   6477096.0
# 22              Michigan   9952687.0
# 23             Minnesota   5241914.0
# ...

# %%
census_df = census_df.drop(census_df.index[51])

# %%
census_df
# Out:
#                    State  Population
# 0                Alabama   4712651.0
# 1                 Alaska    691189.0
# 2                Arizona   6246816.0
# 3               Arkansas   2872684.0
# 4             California  36637290.0
# 5               Colorado   4887061.0
# 6            Connecticut   3545837.0
# 7               Delaware    881278.0
# 8   District of Columbia    584400.0
# 9                Florida  18511620.0
# 10               Georgia   9468815.0
# 11                Hawaii   1333591.0
# 12                 Idaho   1526797.0
# 13              Illinois  12745359.0
# 14               Indiana   6417398.0
# 15                  Iowa   3016267.0
# 16                Kansas   2809329.0
# 17              Kentucky   4285828.0
# 18             Louisiana   4429940.0
# 19                 Maine   1327665.0
# 20              Maryland   5696423.0
# 21         Massachusetts   6477096.0
# 22              Michigan   9952687.0
# 23             Minnesota   5241914.0
# ...

# %%
census_df.to_csv("Resources/StatePopulation.csv", index=False, header=True)
